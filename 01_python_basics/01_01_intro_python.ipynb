# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/ZHAW-ZAV/TSO-FS26-students/blob/main/01_python_basics/01_01_intro_python.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # Introduction to Python
#
#
# ## Importing libraries

# %%
# import the whole library
import os

# import a library and give it a specific name
import numpy as np

# import a specific function from a library
from math import sqrt

# How to use the libraries
# example use: get the current working directory
print(os.getcwd())

# example use: create a numpy array
a = np.array([1, 2, 3])

# example use: calculate the square root of 2
print(sqrt(2))
# Out:
# /Users/wate/Documents/GitHub/TSO-FS26-students/01_python_basics
# 1.4142135623730951

# %% [markdown]
# ## Printing

# %%
# simple print statement
print("Hello World!")

# output variables
a = "Hello World!"
print(a)

# formatted print
age = 10
name = "Peter"
print(f"Hello, my name is {name} and I am {age} years old.")

print(f"The data type of age is {type(age)}, and the data type of name is {type(name)}")
# Out:
# Hello World!
# Hello World!
# Hello, my name is Peter and I am 10 years old.
# The data type of age is <class 'int'>, and the data type of name is <class 'str'>

# %% [markdown]
# ## Basic data types
#
# ### Boolean

# %%
# create with "True" or "False", or as a result of a comparison or logical operation
a = True
b = False
c = a and b


print(a & b)
print(a | b)
print((a & b) | (not c))

# %% [markdown]
# ### String

# %%
# create with either "" or '', there is no difference
my_string = "Hello World!"

# length of string
print(len(my_string))

# access by index
print(my_string[0])

# access by slicing
print(my_string[0:5])

# make uppercase
print(my_string.upper())

# replace substring
print(my_string.replace("World", "Peter"))

# find substring
print("World" in my_string)
# Out:
# 12
# H
# Hello
# HELLO WORLD!
# Hello Peter!
# True

# %% [markdown]
# ### List

# %%
# create with []
my_list = [1, 2, 3, 4, 5]

# length of list
print(len(my_list))

# access by index
print(my_list[-1])

# append to list
my_list.append(6)
print(my_list)

# mixed data types
my_list.append("Hello")
print(my_list)
# Out:
# 5
# 5
# [1, 2, 3, 4, 5, 6]
# [1, 2, 3, 4, 5, 6, 'Hello']

# %% [markdown]
# ### Dictionary (dict)

# %%
# create with {}
my_dict = {"name": "MArlies", "age": 10}

# access by key
print(my_dict["name"])

# add new key-value pair
my_dict["height"] = 150
print(my_dict)

# length of dictionary
print(len(my_dict))

# dict of dicts
my_dict = {
    "person1": {"name": "Peter", "age": 10},
    "person2": {"name": "John", "age": 20},
}
print(my_dict)
print(my_dict["person1"]["name"])
# Out:
# MArlies
# {'name': 'MArlies', 'age': 10, 'height': 150}
# 3
# {'person1': {'name': 'Peter', 'age': 10}, 'person2': {'name': 'John', 'age': 20}}
# Peter

# %% [markdown]
# ### None type

# %%
var = None
print(var)

# check if a variable is None
var is None

# %% [markdown]
# ## Flow control
# ### if-elif-else

# %%
var = 10

# simple if-else statement
if var is None:
    print("Variable is None")
else:
    print("Variable is not None")

# if-elif-else statement
if var is None:
    print("Variable is None")
elif var == 10:
    print("Variable is 10")
else:
    print("Variable is not None and not 10")

# %% [markdown]
# ### for loop

# %%
# iterate over range
for i in range(5):
    print(i)

# iterate over list
var = ["Peter", "John", "Mary"]
for name in var:
    print(f"Hello {name}")

# iterate over dictionary: by items
var = {"Peter": 10, "John": 20, "Mary": 30}
for name, age in var.items():
    print(f"{name} is {age} years old")

# iterate over dictionary: by keys
for name in var.keys():
    print(name)
# Out:
# 0
# 1
# 2
# 3
# 4
# Hello Peter
# Hello John
# Hello Mary
# Peter is 10 years old
# John is 20 years old
# Mary is 30 years old
# Peter
# John
# Mary
